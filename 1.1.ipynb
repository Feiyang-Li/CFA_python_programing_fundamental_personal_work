# %% [markdown]
# Question:
# - Assume that I have 5000 in my brokerage account and I decided to invest the entire amount in Procter & Gamble stock with is trading at 142.5 per share. Complete the following tasks:
#     1. Write python code that defines two variables for the account balance and P&G stock price.
#     2. Confirm variable datatypes
#     3. Calculate number of shares that I can buy with available balance in my account.

# %%
# Common I am CS gruduate, team me for coding. :(
totMoney = 5000
PGStockVal = 142.5

# %%
print(type(totMoney))
print(type(PGStockVal))
# Out:
# <class 'int'>
# <class 'float'>

# %%
totNumShare = totMoney / PGStockVal
print(totNumShare - totNumShare % 1)
# Out:
# 35.0
