# %% [markdown]
# # practice
#
# Defines the following two lists:
#
# stocks_names = ['Apple', 'Samsung', 'Alibaba', 'Novo Nordisk', 'Naspers']
# stock_prices = [142, 45, 12, 125, 30]
# Obtains the total number of elements in the “stock_names” list.
#
# Prints out stock names along with their corresponding prices in reversed order. The code should leverage "for" loops and the range() function. (External research is required.) The output should be as follows:
#
# index = 4
# The price of Naspers stock = $30
# index = 3
# The price of Novo Nordisk stock = $125
# index = 2
# The price of Alibaba stock = $12
# index = 1
# The price of Samsung stock = $45
# index = 0
# The price of Apple stock = $142
# Prints out stock names and prices that are located in even index positions only and in reverse order. The code output should be as follows:
#
# index = 4
# The price of Naspers stock = $30
# index = 2
# The price of Alibaba stock = $12
# index = 0
# The price of Apple stock = $142

# %%
stocks_name = ['Apple', 'Samsung', 'Alibaba', 'Novo Nordisk', 'Naspers']
stocks_price = [142, 45, 12, 125, 30]

# %%
# 1
for i in range(len(stocks_name) - 1, -1, -1):
    print("index = {}".format(i))
    print("The price of {} stock = {}".format(stocks_name[i], stocks_price[i]))
# Out:
# index = 4
# The price of Naspers stock = 30
# index = 3
# The price of Novo Nordisk stock = 125
# index = 2
# The price of Alibaba stock = 12
# index = 1
# The price of Samsung stock = 45
# index = 0
# The price of Apple stock = 142

# %%
# 2
for i in range(4, -1, -2):
    print("index = {}".format(i))
    print("The price of {} stock = {}".format(stocks_name[i], stocks_price[i]))
# Out:
# index = 4
# The price of Naspers stock = 30
# index = 2
# The price of Alibaba stock = 12
# index = 0
# The price of Apple stock = 142
