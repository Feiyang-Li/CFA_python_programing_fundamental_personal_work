# %% [markdown]
# # Understanding:
#
# here we are using Yahoo Finance api yfinace tool to obtain market data

# %%
import yfinance as yf
import time
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
# try AAPL
start = time.perf_counter()

stock = yf.Ticker("APPL")

print(stock.info)

end = time.perf_counter()
print("Runned for: ", end - start, "seconds")
# Out:
# {'quoteType': 'MUTUALFUND', 'symbol': 'APPL', 'language': 'en-US', 'region': 'US', 'typeDisp': 'Fund', 'quoteSourceName': 'Delayed Quote', 'triggerable': False, 'customPriceAlertConfidence': 'NONE', 'marketState': 'CLOSED', 'hasPrePostMarketData': False, 'priceHint': 2, 'fullExchangeName': 'YHD', 'corporateActions': [], 'regularMarketTime': 1561759658, 'exchange': 'YHD', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EST', 'gmtOffSetMilliseconds': -18000000, 'market': 'us_market', 'esgPopulated': False, 'sourceInterval': 15, 'exchangeDataDelayedBy': 0, 'tradeable': False, 'cryptoTradeable': False, 'trailingPegRatio': None}
# Runned for:  1.8402956000008999 seconds

# %%
def timeit(func):
    def wrapper(*args, **kwargs):
        start = time.perf_counter()
        result = func(*args, **kwargs)
        end = time.perf_counter()
        print(f"{func.__name__} took {end - start:.6f} seconds")
        return result
    return wrapper

# %%
@timeit
def get5yrStockPriceHistory(stockName):
    now = datetime.now()
    fiveYrBefore = now - relativedelta(years=5)
    stock = yf.Ticker(stockName)
    return stock.history(start=fiveYrBefore, end=now)

# %%
r_now = datetime.now()
r_fiveYrBefore = r_now - relativedelta(years=5)
stock = yf.Ticker("AAPL")
stock.history(start=r_fiveYrBefore, end=r_now).to_csv("AAPL_5yr_history.csv")
# humm, useful

# %%
result_df = get5yrStockPriceHistory("AAPL")
# Out:
# get5yrStockPriceHistory took 2.056441 seconds

# %%
result_df.head(5)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-11-30 00:00:00-05:00  113.864713  117.758522  113.708957  115.889496
# 2020-12-01 00:00:00-05:00  117.797457  120.192148  116.824004  119.462059
# 2020-12-02 00:00:00-05:00  118.780643  120.094810  117.680645  119.812508
# 2020-12-03 00:00:00-05:00  120.240828  120.493928  118.965608  119.676231
# 2020-12-04 00:00:00-05:00  119.345254  119.598354  118.293924  119.004547
#
#                               Volume  Dividends  Stock Splits
# Date
# 2020-11-30 00:00:00-05:00  169410200        0.0           0.0
# 2020-12-01 00:00:00-05:00  127728200        0.0           0.0
# 2020-12-02 00:00:00-05:00   89004200        0.0           0.0
# 2020-12-03 00:00:00-05:00   78967600        0.0           0.0
# 2020-12-04 00:00:00-05:00   78260400        0.0           0.0

# %%
print(stock.info)
# Out:
# {'address1': 'One Apple Park Way', 'city': 'Cupertino', 'state': 'CA', 'zip': '95014', 'country': 'United States', 'phone': '(408) 996-1010', 'website': 'https://www.apple.com', 'industry': 'Consumer Electronics', 'industryKey': 'consumer-electronics', 'industryDisp': 'Consumer Electronics', 'sector': 'Technology', 'sectorKey': 'technology', 'sectorDisp': 'Technology', 'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple Vision Pro, Apple TV, Apple Watch, Beats products, and HomePod, as well as Apple branded and third-party accessories. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications a
# ...

# %%
import json

with open("AAPLINFO.json", "w") as f:
    json.dump(stock.info, f, indent=4, sort_keys=True)

# %% [markdown]
# # Questions:
# Practice Opportunity
# Now that you have learned how to get financial data using the yfinance tool, try the following practice opportunity.
#
# Write a code that performs the following tasks:
#
# Obtain the beta for META, Apple, Spotify, and P&G stocks.
#
# Get the circulating supply and closing price of Bitcoin.
#
# Obtain the volume of Apple transactions on 22 February 2022.
#
# You can access the Coding Lab for this lesson in the box below.
#
# Note that it may take up to five minutes to load the lab. If you still have difficulty accessing the Coding Lab, download the Jupyter Notebook to run the exercise in your local environment (as described in the introductory lesson Environment Setup and Jupyter Notebook Walk-Through):
#
# Get Financial Markets DataDownload Get Financial Markets Data
#
# Once you have completed the practice opportunity, proceed to the next page, where the solution will be provided.

# %%
## Symbols: META -> Meta
# apple -> AAPL
# Spotify -> SPOT
# P&G -> PG
# Bitcoin: BTC-USD

# so to get beta we can just use
import yfinance as fy

metaInfo = fy.Ticker("META").info
appleInfo = fy.Ticker("AAPL").info
sportifyInfo = fy.Ticker("SPOT").info
pAndgInfo = fy.Ticker("PG").info
BitcoinInfo = fy.Ticker("BTC-USD").info

# this is basically an api to access the yahoo finance.

# %%
print("Beta of {} is {}".format("meta", metaInfo["beta"]))
print("Beta of {} is {}".format("apple", appleInfo["beta"]))
print("Beta of {} is {}".format("sportify", sportifyInfo["beta"]))
print("Beta of {} is {}".format("p & g", pAndgInfo["beta"]))
# Out:
# Beta of meta is 1.272
# Beta of apple is 1.109
# Beta of sportify is 1.651
# Beta of p & g is 0.381

# %%
BitcoinInfo
# Out:
# {'companyOfficers': [],
#  'blockNumber': 771565,
#  'blockReward': 6.25,
#  'blockRewardReduction': '50%',
#  'netHashesPerSecond': '244051282584378770000',
#  'name': 'Bitcoin',
#  'startDate': 1278979200,
#  'description': 'Bitcoin (BTC) is a cryptocurrency launched in 2010. Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 19,955,253. The last known price of Bitcoin is 90,619.88770787 USD and is down -1.04 over the last 24 hours. It is currently trading on 12488 active market(s) with $55,040,289,893.17 traded over the last 24 hours. More information can be found at https://bitcoin.org/.',
#  'executiveTeam': [],
#  'whitepaper': 'https://bitcoin.org/bitcoin.pdf',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 91305.56,
#  'open': 91305.56,
#  'dayLow': 90304.22,
#  'dayHigh': 92945.34,
#  'regularMarketPreviousClose': 91305.56,
#  'regularMarketOpen': 91305.56,
#  'regularMarketDayLow': 90304.22,
# ...

# %%
print("Bitcoin circulation supply of {} with maximum supply of {}".format(BitcoinInfo["circulatingSupply"], BitcoinInfo["maxSupply"]))
# Out:
# Bitcoin circulation supply of 19955036 with maximum supply of 21000000

# %%
# now get the volumn of transaction at specific date:
import datetime

selectDate = datetime.datetime(2022, 2, 22)
history_of_apple_at_2022_2_22 = fy.Ticker("AAPL").history(start=selectDate, end=selectDate+relativedelta(days=1))

# %%
history_of_apple_at_2022_2_22
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-02-22 00:00:00-05:00  161.796116  163.473122  159.020729  161.148865
#
#                              Volume  Dividends  Stock Splits
# Date
# 2022-02-22 00:00:00-05:00  91162800        0.0           0.0

# %%
volume_of_apple_at_2022_2_22 = history_of_apple_at_2022_2_22["Volume"]

# %%
print(int(volume_of_apple_at_2022_2_22.iloc[0]))
# Out:
# 91162800
