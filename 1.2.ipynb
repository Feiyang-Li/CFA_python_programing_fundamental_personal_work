# %% [markdown]
# # Practice Opportunity
# Now that you have met Python’s print() function and associated methods, try the following exercise:
#
# Write some Python code that prints the following message to the screen:
#
# “Procter and Gamble (P&G), which reports using US GAAP, sold a piece of land for $500000”
#
# Generalize your code to the company name, reporting standard, and dollar amount. (Hint: You will need to define three variables for company name, reporting standard, and dollar amount and use the format method with the print function.)
#
# Test your code, and perform a sanity check.

# %%
companyName = "Procter and Gamble (P&G)"
reportingStandard = "US GAAP"
dollarAmount = "$500000"

print("{}, which reports using {}, sold a piece of land for {}".format(companyName, reportingStandard, dollarAmount))
# Out:
# Procter and Gamble (P&G), which reports using US GAAP, sold a piece of land for $500000
