# %% [markdown]
# # Practice Opportunity
# Now that you have learned to harness the power of functions in Python, try the following practice opportunity.
#
# Assume that you have been tasked to develop a Python function that calculates the effective annual rate (EAR) of return. EAR considers the effect of compounding within the year and can be calculated from the nominal (or stated) annual rate of return (𝑖) using the following formula:
#
# EAR = (1 + 𝑖/𝑚)^𝑚 – 1,
#
# where 𝑚 represents the number of compounding periods per year.
#
# Complete the following tasks:
#
# Define a Python function that calculates the effective annual rate of return. The function should receive the nominal (stated) annual rate and the number of compounding periods per year.
#
# Assume that you deposited $1,000 today into an account paying 10% compounded quarterly. Calculate the effective annual rate of return using the function defined in Task 1. Round your answer to four decimal places.
#
# Calculate the amount of interest you would have earned by the end of the year. Round your answer to four decimal places.
#
# Repeat Tasks 2 and 3, but with interest compounded monthly.

# %%
def cal_effective_annual_rate_of_return(norminal_rate: float, num_compounding: int):
    """ 
    Calculation of the effective annual rate of return
    """
    return (1 + norminal_rate / num_compounding) ** num_compounding - 1

# %%
answer1 = 1000 * (cal_effective_annual_rate_of_return(0.1, 4))
answer2 = 1000 * (cal_effective_annual_rate_of_return(0.1, 12))

# %%
print(answer1)
print(answer2)
# Out:
# 103.81289062499954
# 104.71306744129683
