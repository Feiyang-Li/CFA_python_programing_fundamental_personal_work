# %%
# lets create monte Carlos simulation from the start, find the best composition of stock of 
#   what I think is interesting, with 5 years range

# %%
import yfinance as yf
from generalImport import *
from util import *

# %%
# the research question is:
#   - If we assuming past history representing future then what portfolio combaination
#      provide best return, with higher Share Ratio, and how much would I earn?
#   - This is basically assuming we buy 5 years early with a weight, and which weight will
#      give me the best return for today

# %%
# 1. lets first find information of stock that we are interesting in
#   We must first decide stock portfolio::
#   What is my time horizon?
#       I am young, I have a long realistic time horizon investment, but I am here for analysis
#       the market, I want to try earn money in shart term to test my ability. 
#   Risk tolerance:
#       Low
#    Involvement:
#       Applying my understanding in CFA for the real life stock; therefore high involvement.

#   What is my investment method? How I want to analysis?
#      Hedging? Take market advantage? Real value investment? Speculative?  
#      What I am investing is the future of a company, a country, or an idea, it is not about
#      Value (although it matter for purchasing), I am a speculative investor, predicting a country, and industry, and a company's future
#      I analysis the potential of the world and profit from such. 
#
#  Ok in such case, where do I want to start? How about the solar energy future?
#
